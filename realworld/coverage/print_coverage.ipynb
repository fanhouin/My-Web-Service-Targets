# %%
import matplotlib.pyplot as plt
prev = 0
find = False

def getCoverage(file):
    theTime = []
    theData = []
    with open(file, 'r') as f:
        for line in f:
            nums = line.split()
            # if(prev != int(nums[0]) or find == False):
            # 	prev = int(nums[0])
            # 	continue
            # else:
            # 	find = True
            theTime.append(int(nums[0]))
            theData.append(int(nums[2]))
    return theTime, theData

def drawCoverage(file):
    time, data = getCoverage(f'{file}.txt')
    plt.plot(time, data, label=file)

def main():
    drawCoverage('APIScryer-thread')
    drawCoverage('APIScryer')
    drawCoverage('Hsuan-Fuzz')
    drawCoverage('evomaster')
    drawCoverage('restler')
    plt.xlabel('execution time (second)')
    plt.ylabel('code coverage')
    plt.title("Articles + Users")
    plt.grid()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.22), ncol=3)
    plt.show()
    pass

if __name__ == '__main__':
    main()

# %%
import matplotlib.pyplot as plt
prev = 0
find = False

def getCoverage(file):
    theTime = []
    theData = []
    with open(file, 'r') as f:
        for line in f:
            nums = line.split()
            # if(prev != int(nums[0]) or find == False):
            # 	prev = int(nums[0])
            # 	continue
            # else:
            # 	find = True
            theTime.append(int(nums[0]))
            theData.append(int(nums[3]))
    return theTime, theData

def drawCoverage(file):
    time, data = getCoverage(f'{file}.txt')
    plt.plot(time, data, label=file)

def main():
    drawCoverage('APIScryer-thread')
    drawCoverage('APIScryer')
    drawCoverage('Hsuan-Fuzz')
    drawCoverage('evomaster')
    drawCoverage('restler')
    plt.xlabel('execution time (second)')
    plt.ylabel('code coverage')
    plt.title("Articles")
    plt.grid()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.22), ncol=3)
    plt.show()
    pass

if __name__ == '__main__':
    main()

# %%
import matplotlib.pyplot as plt
prev = 0
find = False

def getCoverage(file):
    theTime = []
    theData = []
    with open(file, 'r') as f:
        for line in f:
            nums = line.split()
            # if(prev != int(nums[0]) or find == False):
            # 	prev = int(nums[0])
            # 	continue
            # else:
            # 	find = True
            theTime.append(int(nums[0]))
            theData.append(int(nums[4]))
    return theTime, theData

def drawCoverage(file):
    time, data = getCoverage(f'{file}.txt')
    plt.plot(time, data, label=file)

def main():
    drawCoverage('APIScryer-thread')
    drawCoverage('APIScryer')
    drawCoverage('Hsuan-Fuzz')
    drawCoverage('evomaster')
    drawCoverage('restler')
    plt.xlabel('execution time (second)')
    plt.ylabel('code coverage')
    plt.title("Users")
    plt.grid()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.22), ncol=3)
    plt.show()
    pass

if __name__ == '__main__':
    main()
